# %%
import numpy as np
import pandas as pd
from utils

# %%
data = pd.read_csv('2020-21.csv')

# %%
data['H21'].isnull().sum()
# Out:
# 1037

# %%
data.shape
# Out:
# (36113, 57)

# %%
listado = ['CODI_PROVINCIA', 'CODI_MUNICIPI', 'MUNICIPI']
data.drop(columns=listado)
# Out:
#        PROVINCIA  ESTACIO  CODI_CONTAMINANT   ANY  MES  DIA   H01 V01   H02  \
# 0      Barcelona        4                 7  2020    1    1   3.0   V   3.0
# 1      Barcelona        4                 7  2020    1    2  13.0   V   7.0
# 2      Barcelona        4                 7  2020    1    3  33.0   V  13.0
# 3      Barcelona        4                 7  2020    1    4  12.0   V  11.0
# 4      Barcelona        4                 7  2020    1    5   1.0   V   1.0
# ...          ...      ...               ...   ...  ...  ...   ...  ..   ...
# 36108  Barcelona       58                14  2021   12   26  51.0   V  28.0
# 36109  Barcelona       58                14  2021   12   27   4.0   V   4.0
# 36110  Barcelona       58                14  2021   12   28   4.0   V   4.0
# 36111  Barcelona       58                14  2021   12   29  57.0   V  56.0
# 36112  Barcelona       58                14  2021   12   30  53.0   V  53.0
#
# ...

# %%
condicion = data.iloc[:,10::2]

# %%
data_cleaned = data[-(data == 'N')]

# %%
data_cleaned.dropna()
# Out:
#        PROVINCIA  ESTACIO  CODI_CONTAMINANT   ANY  MES  DIA   H01 V01   H02  \
# 0      Barcelona        4                 7  2020    1    1   3.0   V   3.0
# 4      Barcelona        4                 7  2020    1    5   1.0   V   1.0
# 12     Barcelona        4                 7  2020    1   13  35.0   V  40.0
# 15     Barcelona        4                 7  2020    1   16  18.0   V  25.0
# 17     Barcelona        4                 7  2020    1   18  11.0   V   5.0
# ...          ...      ...               ...   ...  ...  ...   ...  ..   ...
# 36107  Barcelona       58                14  2021   12   25  50.0   V  42.0
# 36108  Barcelona       58                14  2021   12   26  51.0   V  28.0
# 36109  Barcelona       58                14  2021   12   27   4.0   V   4.0
# 36111  Barcelona       58                14  2021   12   29  57.0   V  56.0
# 36112  Barcelona       58                14  2021   12   30  53.0   V  53.0
#
# ...

# %%
#listado = ['CODI_PROVINCIA', 'CODI_MUNICIPI', 'MUNICIPI']
listado = ['PROVINCIA']
data_cleaned = data_cleaned.drop(columns=listado)

# %%
data_cleaned
# Out:
#        ESTACIO  CODI_CONTAMINANT   ANY  MES  DIA   H01 V01   H02 V02   H03  \
# 0            4                 7  2020    1    1   3.0   V   3.0   V   2.0
# 1            4                 7  2020    1    2  13.0   V   7.0   V   6.0
# 2            4                 7  2020    1    3  33.0   V  13.0   V  16.0
# 3            4                 7  2020    1    4  12.0   V  11.0   V  10.0
# 4            4                 7  2020    1    5   1.0   V   1.0   V   2.0
# ...        ...               ...   ...  ...  ...   ...  ..   ...  ..   ...
# 36108       58                14  2021   12   26  51.0   V  28.0   V   4.0
# 36109       58                14  2021   12   27   4.0   V   4.0   V   4.0
# 36110       58                14  2021   12   28   4.0   V   4.0   V   4.0
# 36111       58                14  2021   12   29  57.0   V  56.0   V  56.0
# 36112       58                14  2021   12   30  53.0   V  53.0   V  56.0
#
#        ...   H20  V20   H21  V21   H22  V22   H23  V23   H24  V24
# ...

# %%
mediciones = integratemetadata()
hours = ["H01","H02","H03","H04","H05","H06","H07","H08","H09","H10","H11","H12","H13","H14","H15","H16","H17","H18","H19","H20","H21","H22","H23","H24"]
long_mediciones = pd.melt(mediciones, id_vars=['ESTACIO', 'CONTAMINANTE'], value_vars=hours)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9176/967584726.py in <module>
# ----> 1 mediciones = integratemetadata()
#       2 hours = ["H01","H02","H03","H04","H05","H06","H07","H08","H09","H10","H11","H12","H13","H14","H15","H16","H17","H18","H19","H20","H21","H22","H23","H24"]
#       3 long_mediciones = pd.melt(mediciones, id_vars=['ESTACIO', 'CONTAMINANTE'], value_vars=hours)
#
# NameError: name 'integratemetadata' is not defined
